# %%
import joblib
a = joblib.load("../data/pkls/log_data.pkl")

# %%
a[3886768]
# Out:
# {'version': 3,
#  'teams': {'Red': {'score': 2,
#    'kills': 66,
#    'deaths': 0,
#    'dmg': 31151,
#    'charges': 6,
#    'drops': 2,
#    'firstcaps': 2,
#    'caps': 10},
#   'Blue': {'score': 3,
#    'kills': 56,
#    'deaths': 0,
#    'dmg': 31659,
#    'charges': 9,
#    'drops': 0,
#    'firstcaps': 5,
#    'caps': 15}},
#  'length': 1865,
#  'players': {'[U:1:159413592]': {'team': 'Blue',
#    'class_stats': [{'type': 'scout',
#      'kills': 9,
#      'assists': 9,
#      'deaths': 7,
#      'dmg': 5201,
#      'weapon': {'the_winger': {'kills': 1,
#        'dmg': 135,
#        'avg_dmg': 11.25,
#        'shots': 0,
#        'hits': 0},
#       'scattergun': {'kills': 8,
#        'dmg': 5066,
#        'avg_dmg': 19.33587786259542,
#        'shots': 0,
#        'hits': 241}},
#      'total_time': 1747},
#     {'type': 'pyro',
#      'kills': 2,
#      'assists': 1,
#      'deaths': 2,
#      'dmg': 1105,
#      'weapon': {'detonator': {'kills': 0,
#        'dmg': 597,
# ...
