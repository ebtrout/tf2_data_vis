# %%
import joblib
import pandas as pd

df_dict = joblib.load("data/pkls/rgl_df_dict.pkl")

# %%
# Save into csv
for key in df_dict.keys():
    df = df_dict[key]
    name = f'data/RGL/{key}.csv'
    df.to_csv(name)
# Out:
# {'info':          id  length                  map                              title  \
#  0   3868244    2493      koth_bagel_rc11             RGL Match #31572:  vs
#  0   3868241    2808      koth_bagel_rc11             RGL Match #31567:  vs
#  0   3868230     365      koth_bagel_rc11             RGL Match #31565:  vs
#  0   3868229    1934      koth_bagel_rc11             RGL Match #31571:  vs
#  0   3868227    1852      koth_bagel_rc11             RGL Match #31570:  vs
#  ..      ...     ...                  ...                                ...
#  0   2029483     653    koth_coalplant_b8     RGL.gg Match Server: PP vs BLU
#  0   1910952    1116  koth_lakeside_final  Atlantis | RGL Prolan: RED vs BLU
#  0   1871769     557    koth_ashville_rc1    RGL.gg Match Server: G$ vs DORA
#  0   1871754     642    koth_ashville_rc1    RGL.gg Match Server: G$ vs DORA
#  0   1864908     577     koth_product_rc8   RGL.gg Match Server: RED vs Gg.$
#
#                    date
# ...
