# %%
import joblib
import pandas as pd

df_dict = joblib.load("data/pkls/rgl_df_dict.pkl")

# %%
# Save into csv
for key in df_dict.keys():
    df = df_dict[key]
    name = f'data/RGL/{key}.csv'
    df.to_csv(name)

# %%
df_dict['rounds']
# Out:
#          id  round  start_time winner firstcap  length  team.Blue.score  \
# 0   3868244      0  1748998413   Blue     Blue     334                1
# 1   3868244      1  1748998757    Red      Red     351                1
# 2   3868244      2  1748999118    Red      Red     350                1
# 3   3868244      3  1748999478   Blue      Red     388                2
# 4   3868244      4  1748999876   Blue     Blue     391                3
# ..      ...    ...         ...    ...      ...     ...              ...
# 1   1871769      1  1509653310    Red      Red     253                0
# 0   1871754      0  1509652328    Red      Red     280                0
# 1   1871754      1  1509652613    Red      Red     362                0
# 0   1864908      0  1508779467   Blue     Blue     281                1
# 1   1864908      1  1508779753   Blue     Blue     296                2
#
#     team.Blue.kills  team.Blue.dmg  team.Blue.ubers  team.Red.score  \
# ...
