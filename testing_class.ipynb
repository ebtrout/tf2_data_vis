# %%
import importlib
import data
import joblib
import create_datasets
importlib.reload(data)
importlib.reload(create_datasets)


from data import data

# %%
saved_logs = joblib.load('data/pkls/rgl_matches_pre_manip.pkl')
all_logs = joblib.load('data/pkls/rgl_log_info.pkl')

# %%
a = data(saved_logs[10],'11')
a.info
# Out:
#    id  length              map                       title                date
# 0  11    1728  cp_gullywash_f9  RGL Match #30850: LR vs G6 2025-04-06 00:51:19

# %%
a.players
# Out:
# metric          assists cpc dapd dapm deaths   dmg dmg_real drops    dt  \
# steamid
# [U:1:122797343]       8   6  629  305     14  8811      917     0  8382
# [U:1:151404046]      11   1  432  285     19  8218      668     0  7523
# [U:1:175890948]      15   8   66   18      8   533      123     0  3658
# [U:1:190301470]      18  11  371  193     15  5577      575     0  5233
# [U:1:247981557]      16   3   26   11     13   344       12     0  3630
# [U:1:335448112]       8   0  313  283     26  8159      776     0  7273
# [U:1:59056350]       10  16  291  192     19  5532      331     0  5799
# [U:1:85413659]        5   2  255  257     29  7406      784     0  8361
# [U:1:85442180]       10   4  429  253     17  7301      661     0  7452
# [U:1:87548232]        8  10  763  291     11  8399     1308     0  7344
# [U:1:89112868]        6   2  335  290     25  8378     1411     0  6518
# [U:1:89195940]       10  11  472  279     17  8038      912     0  5523
#
# metric          dt_real  ...    hr kapd kills  kpd medkits medkits_hp  \
# steamid                  ...
# [U:1:122797343]     691  ...  8991  1.9    19  1.4      45       1777
# [U:1:151404046]     707  ...  6456  1.5    17  0.9      67       2631
# [U:1:175890948]     268  ...     0  2.4     4  0.5      10        359
# [U:1:190301470]     649  ...  4837  2.3    16  1.1       7        195
# [U:1:247981557]     581  ...     0  1.3     1  0.1       9        168
# [U:1:335448112]     638  ...  6105  1.1    20  0.8      48       1533
# [U:1:59056350]      920  ...  3704  1.2    12  0.6      16        457
# [U:1:85413659]     1262  ...  6523  0.7    16  0.6      30       1198
# [U:1:85442180]      931  ...  8390  1.4    14  0.8      31       1116
# [U:1:87548232]      503  ...  9564  4.1    37  3.4      10        195
# [U:1:89112868]      713  ...  4962  1.2    25  1.0      79       2669
# [U:1:89195940]      615  ...  6637  2.5    32  1.9       5         88
#
# metric          sentries suicides  team  ka
# steamid
# [U:1:122797343]        0        0   Red  27
# [U:1:151404046]        0        0   Red  28
# [U:1:175890948]        0        0  Blue  19
# [U:1:190301470]        0        0  Blue  34
# [U:1:247981557]        0        0   Red  17
# [U:1:335448112]        0        0  Blue  28
# [U:1:59056350]         0        0   Red  22
# [U:1:85413659]         0        0  Blue  21
# [U:1:85442180]         0        0  Blue  24
# [U:1:87548232]         0        0  Blue  45
# [U:1:89112868]         0        0   Red  31
# [U:1:89195940]         0        0   Red  42
#
# [12 rows x 21 columns]
